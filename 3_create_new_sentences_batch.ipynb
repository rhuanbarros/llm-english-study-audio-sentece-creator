# %%
# from langchain_google_genai import ChatGoogleGenerativeAI

# # llm = ChatGoogleGenerativeAI(model="gemini-pro", convert_system_message_to_human=True, google_api_key="AIzaSyC-V6lfROehy46ntB6zPZ7CJ8zNF3gDdO4")
# # llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest", convert_system_message_to_human=True, google_api_key="AIzaSyC-V6lfROehy46ntB6zPZ7CJ8zNF3gDdO4")
# llm = ChatGoogleGenerativeAI(model="gemini-1.5-pro-latest", convert_system_message_to_human=True, google_api_key="AIzaSyClqzPkQR8HlCfvztCYTuv35hmNxRYqZ58")

# %%
from langchain_community.llms import Ollama
llm = Ollama(
    model="llama2:7b", 
    base_url = 'http://host.docker.internal:11434'
    )

# %%
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template(
    """
    I'm studying english to get a machine learning job in a IT company. 
    I will provide you with a list of sentences from an english book. 
    I need you to change each sentence to a similiar sentence, but using vocabulary from another range of domain like work, meetings, machine learning, development, programming.
    You could use words to persons like developer, programmer, etc.

    Also, each sample conversation starts with "Conversation, Lesson #" with the number of the lesson. 
    You should repeat the title and you should put a "-separator-" after it to separate it from the sentences.
    You should mantain the overall structyure of data to process.

    Abstain of creating explanatory pieace of text like: "Here is your answer as you asked, new english senteces etc...
    You should not print "# NEW DATA TO PROCESS:" as this is just a piece of text to explain where the text to process start. 
    The content you output will be used in a programatic way.

    You should answer only with the convesation title and the new senteces, you shold not output the original text or something like this.

    # NEW DATA TO PROCESS:

    {new_data_to_process}

    """
)

# %%
chain = prompt | llm

# %%
import pandas as pd

# %%
df = pd.read_csv("transcript_separated.csv")
df
# Out:
#     Unnamed: 0                 Filename  \
# 0            0   Wizard-Lesson 1-01.wma
# 1            1  Wizard-Lesson 10-10.wma
# 2            2  Wizard-Lesson 11-11.wma
# 3            3  Wizard-Lesson 12-12.wma
# 4            4  Wizard-Lesson 13-13.wma
# 5            5  Wizard-Lesson 14-14.wma
# 6            6  Wizard-Lesson 14-14.wma
# 7            7  Wizard-Lesson 15-15.wma
# 8            8  Wizard-Lesson 16-16.wma
# 9            9  Wizard-Lesson 17-17.wma
# 10          10  Wizard-Lesson 18-18.wma
# 11          11  Wizard-Lesson 19-19.wma
# 12          12   Wizard-Lesson 2-02.wma
# 13          13  Wizard-Lesson 20-20.wma
# 14          14  Wizard-Lesson 21-21.wma
# 15          15  Wizard-Lesson 22-22.wma
# 16          16  Wizard-Lesson 23-23.wma
# 17          17  Wizard-Lesson 24-24.wma
# 18          18  Wizard-Lesson 25-25.wma
# 19          19  Wizard-Lesson 26-26.wma
# 20          20  Wizard-Lesson 27-27.wma
# 21          21  Wizard-Lesson 28-28.wma
# 22          22  Wizard-Lesson 29-29.wma
# 23          23   Wizard-Lesson 3-03.wma
# 24          24  Wizard-Lesson 30-30.wma
# 25          25   Wizard-Lesson 4-04.wma
# 26          26   Wizard-Lesson 5-05.wma
# 27          27   Wizard-Lesson 6-06.wma
# 28          28   Wizard-Lesson 7-07.wma
# 29          29   Wizard-Lesson 8-08.wma
# 30          30   Wizard-Lesson 9-09.wma
#
#                                             Sentences  \
# 0    Music  Wizard Book 3 Conversation Lesson 1  D...
# 1    Conversation, Lesson 10, is he younger or old...
# 2    Lesson 11  Conversation Lesson 11  Lesson 11 ...
# 3    Conversation  Lesson 12  She put her sunglass...
# 4    Conversation  Lesson 13  He invited Sandy to ...
# 5    Conversation  Lesson 14  She left her laptop ...
# 6    Conversation  Lesson 14  She left her laptop ...
# 7    Conversation, Lesson 15  There's an employee ...
# 8    Conversation lesson 16  Is there a padlock on...
# 9    Conversation, lesson 17.  Are there sandwiche...
# 10   Conversation  Lesson 18  Was there a car in t...
# 11   Conversation  Lesson 19  What did he save?  H...
# 12   Conversation.  Lesson 2.  Where did she put t...
# 13   Conversation, Lesson 20  He always goes joggi...
# 14   Conversation  Lesson 21  I don't know if she ...
# 15   Conversation lesson 22  She can help us.  Whe...
# 16   Conversation  Lesson 23  Should we go now or ...
# 17   Conversation  Lesson 24  He should sleep on t...
# 18   Conversation Lesson 25 She will talk to the s...
# 19   Conversation  Conversation  Lesson 26  When w...
# 20   Conversation Lesson 27  She would like to go ...
# 21   Conversation  Lesson 28  The manager would li...
# 22   Conversation  Conversation  Lesson 29  What a...
# 23   Conversation  Lesson 3  What did they do?  Th...
# 24   Conversation  Lesson 30  She is going to use ...
# 25   Conversation  Lesson 4  What did Sally play? ...
# 26   Conversation  Lesson 5  He took classes at th...
# 27   Conversation, lesson six.  I don't know if sh...
# 28   Conversation Lesson 7  They took a trip to Eu...
# 29   Conversation. Lesson 8. They left the house a...
# 30   Conversation, Lesson 9  The boy saw an empty ...
#
#                                   Sentences_separated
# 0   \nWIZARD Book 3 Conversation\nLesson 1\n-separ...
# 1   \nConversation, Lesson 10\n-separator-\nIs he ...
# 2   \nWIZARD Book 3 Conversation Lesson 11\n\n-sep...
# 3   \nConversation Lesson 1\n-separator-\nDid she ...
# 4   \nConversation Lesson 13\n-separator-\nDid San...
# 5   \nConversation Lesson 14\n-separator-\nDid she...
# 6   \nConversation, Lesson 1\nDid the boy pay $1 f...
# 7   \nConversation, Lesson 1\nDid the boy pay $1 f...
# 8   \nConversation, Lesson #16\n\nIs there a padlo...
# 9   \nConversation, Lesson 17\nAre there sandwiche...
# 10  \nConversation, Lesson 18\n-separator-\nWas th...
# 11  \nConversation, Lesson 19\n-separator-\nWhat d...
# 12  \nConversation Lesson 1\n-separator-\nDid she ...
# 13  \nConversation, Lesson 10\n-separator-\nDid he...
# 14  \nConversation, Lesson 1\n-separator-\nDid the...
# 15  \nWIZARD Book 3 Conversation\nLesson 22\n-sepa...
# 16  \nConversation, Lesson 1\nDid the boy pay $1 f...
# 17  \nConversation, Lesson 1 -separator- Did he pa...
# 18  \nConversation Lesson 1\n-separator-\nDid the ...
# 19  \nWIZARD Book 3 Conversation Lesson 26\n-separ...
# 20  \nConversation, Lesson 1\n-separator-\nDid the...
# 21  \nConversation, Lesson 28\n-separator-\nDid th...
# 22  \nConversation, Lesson 1\n-separator-\nDid the...
# 23  \nConversation Lesson 1\n-separator-\nDid you ...
# 24  \nConversation, Lesson 1\n-separator-\nDid she...
# 25  \nConversation Lesson 1\nDid the boy pay $1 fo...
# 26  \nWIZARD Book 3 Conversation\nLesson 5\n-separ...
# 27  \nConversation, Lesson 6\n-separator-\nDid she...
# 28  \nConversation, Lesson 1\n-separator-\nDid the...
# 29  \nConversation, Lesson 1\nDid the boy pay $1 f...
# 30  \nConversation, Lesson 9\n-separator-\nWhere d...

# %%
data = []

# %%
for i, row in df.iloc[:].iterrows():
    print(i, row["Filename"])
    # print( row["Sentences"] )
    
    response = chain.invoke({"new_data_to_process": row["Sentences"]})

    data.append( response )
    
    if i==0:
        break
# Out:
# 0 Wizard-Lesson 1-01.wma
#  Music  Wizard Book 3 Conversation Lesson 1  Did the boy pay $1 for the paper at the newsstand?  Yes, he did. He paid $1 for the paper at the newsstand.  Did this secretary put the document on the table?  Yes, she did.  She put the document on the table.  No, she didn't.  She didn't put the information from the computer?  Yes, I did. I accessed the information from the computer.  No, I didn't. I didn't access the information from the computer.  Did your mom do her Christmas shopping early this year?  Yes, she did.  She did her Christmas shopping early this year.  No, she didn't. She didn't do her Christmas shopping early this year.  Did they eat Brazilian food at the restaurant? Yes, they did.  They ate Brazilian food at the restaurant.  No, they didn't.  They didn't eat Brazilian food at the restaurant. Is your sister doing her homework in the her bedroom?  Yes, she is.  She is doing her homework in her bedroom.  No, she isn't. She isn't doing her homework in her bedroom.  Are the children playing in the snow?  Yes, they are. They are playing in the snow.  Now they aren't. They aren't playing in the snow.  Is your son putting the toys in the room?  Yes he is.  He is putting the toys in the room.  No, he isn't. He isn't putting the toys in the room.  Is Jane accessing her email every day?  Yes she is. She is accessing her email every day. No, she isn't. She isn't accessing her email every day.  Is the man paying for the groceries?  Yes he is.  He is paying for the groceries.  No he isn't.  He is not paying for the groceries.

# %%
response
# Out:
# '\nSure, I can help you with that! Please provide me with the list of sentences from the English book, and I will happily assist you in creating new sentences using vocabulary from different domains such as work, meetings, machine learning, development, programming.'

# %%
data
# Out:
# ['\nSure, I can help you with that! Please provide me with the list of sentences from the English book, and I will change each sentence to a similar sentence using vocabulary from another domain such as work, meetings, machine learning, development, programming. I will repeat the title and add a "-separator-" after it to separate it from the new sentences. Please let me know if you have any specific requirements or guidelines for the new sentences.']

# %%
df.iloc[0, 1]
# Out:
# 'Wizard-Lesson 1-01.wma'

# %%
df["Sentences_new"] = data

# %%
df.to_csv( "transcript_new_sentences.csv", index=False )
